# %%
import numpy as np
from scipy.stats import qmc
import matplotlib.pyplot as plt

# %%
sampler = qmc.Sobol(d=2, scramble=False)
samples = sampler.random(4)

plt.scatter(samples[:,0], samples[:,1])

# %%
samples
# Out:
# array([[0.  , 0.  ],
#        [0.5 , 0.5 ],
#        [0.75, 0.25],
#        [0.25, 0.75]])
