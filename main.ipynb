# %%
import numpy as np
from bed.cli.main import run_experiment_from_config
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
results = run_experiment_from_config('experiment_4')
# Out:
# ...
# Running EIG Experiment: 100%|███████████████████████████████████████████████████| 190/190 [11:14<00:00,  3.55s/it, Global SD=2.87, Pool SD=2.47, Global RMSE=9.60, Pool RMSE=10.38, EIG=4.52]

# %%
epig_results = results.experiment_results_list[0]
eig_results  = results.experiment_results_list[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 epig_results = results.experiment_results_list[0]
# ----> 2 eig_results  = results.experiment_results_list[1]
#
# IndexError: list index out of range

# %%
plt.plot(epig_results.sd_glob)
plt.plot(eig_results.sd_glob)

# %%
plt.plot(epig_results.sd_pool[:10])
plt.plot(eig_results.sd_pool[:10])

# %%
plt.plot(epig_results.rmse_pool)
plt.plot(eig_results.rmse_pool)

# %%
plt.plot(epig_results.rmse_glob)
plt.plot(eig_results.rmse_glob)

# %%
plt.plot(epig_results.crit_values)

# %%
import

# %%
np.unique(epig_results.designs.squeeze(),axis=0).shape
# Out:
# (3, 8)
